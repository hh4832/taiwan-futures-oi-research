# %% [markdown]
# # 03 — Experiment Sandbox
#
# Use this notebook for one-variable-at-a-time experiments. Promote stable logic into `src/` after validation.

# %%
import pandas as pd
daily = pd.read_parquet("outputs/daily_dataset.parquet")
results = pd.read_csv("outputs/primary_results.csv")

# %% [markdown]
# ### Example experiment
# Change only one core variable, e.g. the rolling window from 252 to 126 days. Record:
# - problem being addressed
# - expected metric change
# - possible side effect
# - actual result
# - conclusion: 保留 / 修改後再測 / 淘汰

# %%
# Put temporary experimental analysis here.
# Do not overwrite src/config.py until the result is intentionally promoted.
